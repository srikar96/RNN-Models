# %% [markdown]
# ## Character Level Language Modelling
#
# In Character Level modelling, we try to predict character by character from a trained model. This requires us to use a Many to many RNN model where given an initial input character, the RNN outputs the next character in the sequence.
#
# In this particular notebook, I've used an LSTM as the choice of RNN.

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ### Dataset

# %% [markdown]
# I've used baby names dataset from the internet to generate new names and see how well the model is able to generate. I also tried Dinosaur names (this was used in one of Coursera's assignments in the Sequence Models course) but it would work for any kind of datset.
#
# The dataset has a few 100 names seperated by the new line character.

# %%
file = open('names.txt', 'r') # Replace the file with any document which contains a list of names
file = file.read()
file = file.lower()

# %%
print(file[:100])
# Out:
# emma
# olivia
# ava
# isabella
# sophia
# charlotte
# mia
# amelia
# harper
# evelyn
# abigail
# emily
# elizabeth
# mila
# ella

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Find the unique characters in the dataset.
#
# Create two dictionaries to hold the mapping from characters to numbers and numbes to characters.

# %%
unique = sorted(list(set(file)))
num_char = {i:j for i,j in enumerate(unique)} # numbers to characters
char_num = {j:i for i,j in num_char.items()} # characters to numbers
vocab_size = len(unique)

# %% [markdown]
# Split the data into a list containing the names and shuffle them.
#
# While training, the input to the model will be the list of names as it is and the output would be the same list of names shifted by one charater to the right. This is because we want the model to predict the next possible character in the sequence.

# %%
data = file.split('\n')
np.random.shuffle(data)

X = data[:]
# Shift the character's by one to the right and append the new line character at the end (both need to be the same length)
Y = [i[1:]+'\n' for i in data] 

# Convert the characters to integers using the char_num mapping
# Since each name can be of different lengths, pad all the names with zeros to make them equal to the length of the maximum name
# in the data set
X_code = tf.keras.preprocessing.sequence.pad_sequences([np.array([char_num[j] for j in i]) for i in X], padding = 'post')
Y_code = tf.keras.preprocessing.sequence.pad_sequences([np.array([char_num[j] for j in i]) for i in Y], padding = 'post')

# Convert the integers to onehot vectors to feed to the model
X_hot = np.array([tf.keras.utils.to_categorical(i, num_classes=vocab_size) for i in X_code])
Y_hot = np.array([tf.keras.utils.to_categorical(i, num_classes=vocab_size) for i in Y_code])

# %%
X_hot.shape # (num of examples, length of each example, dimention of the on hot encoded vector)
# Out:
# (1001, 10, 27)

# %% [markdown]
# ### Model
#
# The input to the model is processed one hot vectors. Each name in the data is one training example. New linr character marks the end of the example.
#
# The next layer consists of 125 LSTMs. We use return sequence as True because this is a many to many RNN model and we need the outputs after each character passes through. We get 16 outputs after the LSTMs process the input sequence which is 16 characters in length. Without the retuen sequences, it would only output the final value after al the 16 characters have been processed.
#
# Finally, since we need a prediction result, pass each of the outputs through a softmax to predict the character.

# %%
inputs = tf.keras.Input(shape=(X_hot.shape[1],X_hot.shape[2]))
x = tf.keras.layers.LSTM(125, activation=tf.nn.relu, return_sequences=True)(inputs)
outputs = tf.keras.layers.Dense(vocab_size, activation=tf.nn.softmax)(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10, 27)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 10, 125)           76500
# _________________________________________________________________
# dense (Dense)                (None, 10, 27)            3402
# =================================================================
# Total params: 79,902
# Trainable params: 79,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# At the end of every few epochs we can view the output of the LSTM by generating new names. Ww need to use callbacks for generating the outputs.
# The function generate_names generates 5 names after every 25 epochs.

# %%
def generate_names(epoch, _):
    if epoch % 25 == 0:
        
        print('\nNames After Epoch {}: '.format(epoch))

        # generate 5 names
        for j in range(5):
            name = ''
            x = np.zeros((1, X_hot.shape[1], vocab_size)) # Initialize a vector of zeros of size (16,27)
            end = False
            i = 0

            # Keep generating new characters untill a new line character is generated or the length of the generated 
            # sequence reaches a certain limit
            # When we use model.predict() it gives us all the 16 outputs but we need to generate one character at a time and feed
            # it as input and again predict the next character and so on
            while (not end):
                probs = list(model.predict(x)[0,i]) # Output of the ith RNN
                probs = probs / np.sum(probs)
                index = np.random.choice(range(vocab_size), p=probs) # randomly choose a character from the generated ones according to their probability
                if i == X_hot.shape[1]-2:
                    character = '\n'
                    end = True
                else:
                    character = num_char[index] # conver the integer to character
                name += character
                x[0, i+1, index] = 1 # Set the input of the next RNN equal to the value generated by the current RNN
                i += 1
                if character == '\n':
                    end = True
            print(name)
    
name_generator = tf.keras.callbacks.LambdaCallback(on_epoch_end = generate_names)

# %%
model.fit(X_hot, Y_hot, epochs=300, callbacks=[name_generator], verbose=1)
# Out:
# Train on 1001 samples
# Epoch 1/300
#  800/1001 [======================>.......] - ETA: 0s - loss: 2.9060 - accuracy: 0.4345
# Names After Epoch 0:
# pwnr
#
# dqlve
#
# pyinam
#
# ohxfen
#
# gmsam
#
# 1001/1001 [==============================] - 2s 2ms/sample - loss: 2.6887 - accuracy: 0.4467
# Epoch 2/300
# 1001/1001 [==============================] - 0s 166us/sample - loss: 1.8006 - accuracy: 0.5045
# Epoch 3/300
# 1001/1001 [==============================] - 0s 173us/sample - loss: 1.6734 - accuracy: 0.5234
# Epoch 4/300
# 1001/1001 [==============================] - 0s 172us/sample - loss: 1.6212 - accuracy: 0.5349
# Epoch 5/300
# 1001/1001 [==============================] - 0s 173us/sample - loss: 1.5838 - accuracy: 0.5465
# Epoch 6/300
# 1001/1001 [==============================] - 0s 168us/sample - loss: 1.5456 - accuracy: 0.5588
# Epoch 7/300
# 1001/1001 [==============================] - 0s 175us/sample - loss: 1.5062 - accuracy: 0.5726
# Epoch 8/300
# 1001/1001 [==============================] - 0s 168us/sample - loss: 1.4719 - accuracy: 0.5809
# Epoch 9/300
# 1001/1001 [==============================] - 0s 169us/sample - loss: 1.4417 - accuracy: 0.5823
# Epoch 10/300
# 1001/1001 [==============================] - 0s 181us/sample - loss: 1.4032 - accuracy: 0.5880
# Epoch 11/300
# 1001/1001 [==============================] - 0s 179us/sample - loss: 1.3741 - accuracy: 0.5947
# Epoch 12/300
# 1001/1001 [==============================] - 0s 183us/sample - loss: 1.3463 - accuracy: 0.6008
# Epoch 13/300
# 1001/1001 [==============================] - 0s 181us/sample - loss: 1.3203 - accuracy: 0.6095
# Epoch 14/300
# 1001/1001 [==============================] - 0s 180us/sample - loss: 1.2957 - accuracy: 0.6143
# Epoch 15/300
# 1001/1001 [==============================] - 0s 162us/sample - loss: 1.2704 - accuracy: 0.6187
# Epoch 16/300
# 1001/1001 [==============================] - 0s 170us/sample - loss: 1.2481 - accuracy: 0.6204
# Epoch 17/300
# 1001/1001 [==============================] - 0s 179us/sample - loss: 1.2272 - accuracy: 0.6271
# Epoch 18/300
# 1001/1001 [==============================] - 0s 181us/sample - loss: 1.2064 - accuracy: 0.6311
# Epoch 19/300
# 1001/1001 [==============================] - 0s 174us/sample - loss: 1.1867 - accuracy: 0.6347
# Epoch 20/300
# 1001/1001 [==============================] - 0s 194us/sample - loss: 1.1762 - accuracy: 0.6357
# Epoch 21/300
# 1001/1001 [==============================] - 0s 182us/sample - loss: 1.1613 - accuracy: 0.6391
# Epoch 22/300
# 1001/1001 [==============================] - 0s 180us/sample - loss: 1.1475 - accuracy: 0.6388
# Epoch 23/300
# 1001/1001 [==============================] - 0s 181us/sample - loss: 1.1293 - accuracy: 0.6489
# Epoch 24/300
# 1001/1001 [==============================] - 0s 171us/sample - loss: 1.1183 - accuracy: 0.6498
# Epoch 25/300
# 1001/1001 [==============================] - 0s 173us/sample - loss: 1.1055 - accuracy: 0.6531
# Epoch 26/300
#  992/1001 [============================>.] - ETA: 0s - loss: 1.0967 - accuracy: 0.6533
# Names After Epoch 25:
# ailah
#
# cilynh
#
# aelya
#
# zlasy
#
# saria
#
# 1001/1001 [==============================] - 1s 674us/sample - loss: 1.0955 - accuracy: 0.6538
# Epoch 27/300
# 1001/1001 [==============================] - 0s 163us/sample - loss: 1.0879 - accuracy: 0.6568
# Epoch 28/300
# 1001/1001 [==============================] - 0s 184us/sample - loss: 1.0744 - accuracy: 0.6612
# Epoch 29/300
# 1001/1001 [==============================] - 0s 188us/sample - loss: 1.0677 - accuracy: 0.6619
# Epoch 30/300
# 1001/1001 [==============================] - 0s 186us/sample - loss: 1.0532 - accuracy: 0.6666
# Epoch 31/300
# 1001/1001 [==============================] - 0s 186us/sample - loss: 1.0530 - accuracy: 0.6659
# Epoch 32/300
# 1001/1001 [==============================] - 0s 170us/sample - loss: 1.0408 - accuracy: 0.6690
# Epoch 33/300
# 1001/1001 [==============================] - 0s 184us/sample - loss: 1.0340 - accuracy: 0.6702
# Epoch 34/300
# 1001/1001 [==============================] - 0s 183us/sample - loss: 1.0223 - accuracy: 0.6745
# Epoch 35/300
# 1001/1001 [==============================] - 0s 180us/sample - loss: 1.0131 - accuracy: 0.6773
# Epoch 36/300
# 1001/1001 [==============================] - 0s 186us/sample - loss: 1.0084 - accuracy: 0.6792
# Epoch 37/300
# 1001/1001 [==============================] - 0s 176us/sample - loss: 1.0061 - accuracy: 0.6762
# Epoch 38/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.9891 - accuracy: 0.6815
# Epoch 39/300
# 1001/1001 [==============================] - 0s 174us/sample - loss: 0.9861 - accuracy: 0.6807
# Epoch 40/300
# 1001/1001 [==============================] - 0s 174us/sample - loss: 0.9753 - accuracy: 0.6853
# Epoch 41/300
# 1001/1001 [==============================] - 0s 181us/sample - loss: 0.9699 - accuracy: 0.6858
# Epoch 42/300
# 1001/1001 [==============================] - 0s 181us/sample - loss: 0.9629 - accuracy: 0.6881
# Epoch 43/300
# 1001/1001 [==============================] - 0s 186us/sample - loss: 0.9522 - accuracy: 0.6904
# Epoch 44/300
# 1001/1001 [==============================] - 0s 187us/sample - loss: 0.9454 - accuracy: 0.6910
# Epoch 45/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.9392 - accuracy: 0.6934
# Epoch 46/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.9371 - accuracy: 0.6951
# Epoch 47/300
# 1001/1001 [==============================] - 0s 188us/sample - loss: 0.9285 - accuracy: 0.6942
# Epoch 48/300
# 1001/1001 [==============================] - 0s 185us/sample - loss: 0.9278 - accuracy: 0.6974
# Epoch 49/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.9123 - accuracy: 0.7011
# Epoch 50/300
# 1001/1001 [==============================] - 0s 182us/sample - loss: 0.9049 - accuracy: 0.7038
# Epoch 51/300
#  896/1001 [=========================>....] - ETA: 0s - loss: 0.9044 - accuracy: 0.7021
# Names After Epoch 50:
# anror
#
# lienhy
#
# felvie
#
# voreney
#
# iaana
#
# 1001/1001 [==============================] - 1s 723us/sample - loss: 0.9044 - accuracy: 0.7023
# Epoch 52/300
# 1001/1001 [==============================] - 0s 169us/sample - loss: 0.9039 - accuracy: 0.7012
# Epoch 53/300
# 1001/1001 [==============================] - 0s 186us/sample - loss: 0.8871 - accuracy: 0.7076
# Epoch 54/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.8808 - accuracy: 0.7115
# Epoch 55/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.8742 - accuracy: 0.7119
# Epoch 56/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.8689 - accuracy: 0.7125
# Epoch 57/300
# 1001/1001 [==============================] - 0s 182us/sample - loss: 0.8628 - accuracy: 0.7138
# Epoch 58/300
# 1001/1001 [==============================] - 0s 183us/sample - loss: 0.8582 - accuracy: 0.7141
# Epoch 59/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.8531 - accuracy: 0.7168
# Epoch 60/300
# 1001/1001 [==============================] - 0s 189us/sample - loss: 0.8477 - accuracy: 0.7180
# Epoch 61/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.8487 - accuracy: 0.7188
# Epoch 62/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.8317 - accuracy: 0.7257
# Epoch 63/300
# 1001/1001 [==============================] - 0s 179us/sample - loss: 0.8416 - accuracy: 0.7202
# Epoch 64/300
# 1001/1001 [==============================] - 0s 187us/sample - loss: 0.8290 - accuracy: 0.7235
# Epoch 65/300
# 1001/1001 [==============================] - 0s 185us/sample - loss: 0.8239 - accuracy: 0.7239
# Epoch 66/300
# 1001/1001 [==============================] - 0s 195us/sample - loss: 0.8221 - accuracy: 0.7262
# Epoch 67/300
# 1001/1001 [==============================] - 0s 197us/sample - loss: 0.8107 - accuracy: 0.7287
# Epoch 68/300
# 1001/1001 [==============================] - 0s 183us/sample - loss: 0.8034 - accuracy: 0.7293
# Epoch 69/300
# 1001/1001 [==============================] - 0s 185us/sample - loss: 0.8026 - accuracy: 0.7323
# Epoch 70/300
# 1001/1001 [==============================] - 0s 187us/sample - loss: 0.7927 - accuracy: 0.7355
# Epoch 71/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.7853 - accuracy: 0.7362
# Epoch 72/300
# 1001/1001 [==============================] - 0s 184us/sample - loss: 0.7855 - accuracy: 0.7354
# Epoch 73/300
# 1001/1001 [==============================] - 0s 182us/sample - loss: 0.7749 - accuracy: 0.7398
# Epoch 74/300
# 1001/1001 [==============================] - 0s 181us/sample - loss: 0.7754 - accuracy: 0.7385
# Epoch 75/300
# 1001/1001 [==============================] - 0s 173us/sample - loss: 0.7677 - accuracy: 0.7422
# Epoch 76/300
#  896/1001 [=========================>....] - ETA: 0s - loss: 0.7624 - accuracy: 0.7439
# Names After Epoch 75:
# gina
#
# autina
#
# irthra
#
# oha
#
# anisa
#
# 1001/1001 [==============================] - 1s 626us/sample - loss: 0.7632 - accuracy: 0.7435
# Epoch 77/300
# 1001/1001 [==============================] - 0s 162us/sample - loss: 0.7562 - accuracy: 0.7453
# Epoch 78/300
# 1001/1001 [==============================] - 0s 172us/sample - loss: 0.7547 - accuracy: 0.7468
# Epoch 79/300
# 1001/1001 [==============================] - 0s 173us/sample - loss: 0.7516 - accuracy: 0.7487
# Epoch 80/300
# 1001/1001 [==============================] - 0s 178us/sample - loss: 0.7478 - accuracy: 0.7461
# Epoch 81/300
# 1001/1001 [==============================] - 0s 186us/sample - loss: 0.7441 - accuracy: 0.7484
# Epoch 82/300
# 1001/1001 [==============================] - 0s 180us/sample - loss: 0.7327 - accuracy: 0.7538
# Epoch 83/300
# 1001/1001 [==============================] - 0s 185us/sample - loss: 0.7322 - accuracy: 0.7508
# Epoch 84/300
# 1001/1001 [==============================] - 0s 172us/sample - loss: 0.7354 - accuracy: 0.7503
# Epoch 85/300
# 1001/1001 [==============================] - 0s 178us/sample - loss: 0.7282 - accuracy: 0.7517
# Epoch 86/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.7242 - accuracy: 0.7525
# Epoch 87/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.7194 - accuracy: 0.7557
# Epoch 88/300
# 1001/1001 [==============================] - 0s 189us/sample - loss: 0.7090 - accuracy: 0.7578
# Epoch 89/300
# 1001/1001 [==============================] - 0s 171us/sample - loss: 0.7086 - accuracy: 0.7595
# Epoch 90/300
# 1001/1001 [==============================] - 0s 173us/sample - loss: 0.7139 - accuracy: 0.7581
# Epoch 91/300
# 1001/1001 [==============================] - 0s 185us/sample - loss: 0.7058 - accuracy: 0.7582
# Epoch 92/300
# 1001/1001 [==============================] - 0s 181us/sample - loss: 0.6984 - accuracy: 0.7610
# Epoch 93/300
# 1001/1001 [==============================] - 0s 175us/sample - loss: 0.6986 - accuracy: 0.7590
# Epoch 94/300
# 1001/1001 [==============================] - 0s 175us/sample - loss: 0.6956 - accuracy: 0.7618
# Epoch 95/300
# 1001/1001 [==============================] - 0s 181us/sample - loss: 0.6880 - accuracy: 0.7657
# Epoch 96/300
# 1001/1001 [==============================] - 0s 178us/sample - loss: 0.6831 - accuracy: 0.7644
# Epoch 97/300
# 1001/1001 [==============================] - 0s 189us/sample - loss: 0.6880 - accuracy: 0.7636
# Epoch 98/300
# 1001/1001 [==============================] - 0s 193us/sample - loss: 0.6852 - accuracy: 0.7660
# Epoch 99/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.6755 - accuracy: 0.7692
# Epoch 100/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.6734 - accuracy: 0.7693
# Epoch 101/300
#  960/1001 [===========================>..] - ETA: 0s - loss: 0.6691 - accuracy: 0.7703
# Names After Epoch 100:
# hiava
#
# aige
#
# adalyn
#
# lasen
#
# ris
#
# 1001/1001 [==============================] - 1s 616us/sample - loss: 0.6685 - accuracy: 0.7704
# Epoch 102/300
# 1001/1001 [==============================] - 0s 166us/sample - loss: 0.6782 - accuracy: 0.7666
# Epoch 103/300
# 1001/1001 [==============================] - 0s 176us/sample - loss: 0.6702 - accuracy: 0.7690
# Epoch 104/300
# 1001/1001 [==============================] - 0s 178us/sample - loss: 0.6800 - accuracy: 0.7682
# Epoch 105/300
# 1001/1001 [==============================] - 0s 199us/sample - loss: 0.6578 - accuracy: 0.7742
# Epoch 106/300
# 1001/1001 [==============================] - 0s 198us/sample - loss: 0.6560 - accuracy: 0.7751
# Epoch 107/300
# 1001/1001 [==============================] - 0s 196us/sample - loss: 0.6505 - accuracy: 0.7742
# Epoch 108/300
# 1001/1001 [==============================] - 0s 201us/sample - loss: 0.6485 - accuracy: 0.7764
# Epoch 109/300
# 1001/1001 [==============================] - 0s 193us/sample - loss: 0.6473 - accuracy: 0.7764
# Epoch 110/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.6439 - accuracy: 0.7784
# Epoch 111/300
# 1001/1001 [==============================] - 0s 251us/sample - loss: 0.6406 - accuracy: 0.7783
# Epoch 112/300
# 1001/1001 [==============================] - 0s 242us/sample - loss: 0.6450 - accuracy: 0.7759
# Epoch 113/300
# 1001/1001 [==============================] - 0s 250us/sample - loss: 0.6334 - accuracy: 0.7788
# Epoch 114/300
# 1001/1001 [==============================] - 0s 231us/sample - loss: 0.6353 - accuracy: 0.7790
# Epoch 115/300
# 1001/1001 [==============================] - 0s 193us/sample - loss: 0.6361 - accuracy: 0.7799
# Epoch 116/300
# 1001/1001 [==============================] - 0s 202us/sample - loss: 0.6252 - accuracy: 0.7817
# Epoch 117/300
# 1001/1001 [==============================] - 0s 202us/sample - loss: 0.6290 - accuracy: 0.7784
# Epoch 118/300
# 1001/1001 [==============================] - 0s 200us/sample - loss: 0.6187 - accuracy: 0.7817
# Epoch 119/300
# 1001/1001 [==============================] - 0s 203us/sample - loss: 0.6158 - accuracy: 0.7834
# Epoch 120/300
# 1001/1001 [==============================] - 0s 230us/sample - loss: 0.6168 - accuracy: 0.7820
# Epoch 121/300
# 1001/1001 [==============================] - 0s 196us/sample - loss: 0.6124 - accuracy: 0.7836
# Epoch 122/300
# 1001/1001 [==============================] - 0s 194us/sample - loss: 0.6137 - accuracy: 0.7828
# Epoch 123/300
# 1001/1001 [==============================] - 0s 196us/sample - loss: 0.6097 - accuracy: 0.7853
# Epoch 124/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.6092 - accuracy: 0.7841
# Epoch 125/300
# 1001/1001 [==============================] - 0s 210us/sample - loss: 0.6058 - accuracy: 0.7861
# Epoch 126/300
#  864/1001 [========================>.....] - ETA: 0s - loss: 0.6007 - accuracy: 0.7898
# Names After Epoch 125:
# alari
#
# hadassah
#
# heley
#
# ayleigh
#
# oleste
#
# 1001/1001 [==============================] - 1s 815us/sample - loss: 0.6016 - accuracy: 0.7895
# Epoch 127/300
# 1001/1001 [==============================] - 0s 189us/sample - loss: 0.5999 - accuracy: 0.7873
# Epoch 128/300
# 1001/1001 [==============================] - 0s 193us/sample - loss: 0.6032 - accuracy: 0.7901
# Epoch 129/300
# 1001/1001 [==============================] - 0s 201us/sample - loss: 0.5982 - accuracy: 0.7900
# Epoch 130/300
# 1001/1001 [==============================] - 0s 201us/sample - loss: 0.5960 - accuracy: 0.7899
# Epoch 131/300
# 1001/1001 [==============================] - 0s 193us/sample - loss: 0.5936 - accuracy: 0.7888
# Epoch 132/300
# 1001/1001 [==============================] - 0s 213us/sample - loss: 0.5933 - accuracy: 0.7898
# Epoch 133/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.5879 - accuracy: 0.7895
# Epoch 134/300
# 1001/1001 [==============================] - 0s 187us/sample - loss: 0.5892 - accuracy: 0.7887
# Epoch 135/300
# 1001/1001 [==============================] - 0s 197us/sample - loss: 0.5885 - accuracy: 0.7916
# Epoch 136/300
# 1001/1001 [==============================] - 0s 194us/sample - loss: 0.5805 - accuracy: 0.7920
# Epoch 137/300
# 1001/1001 [==============================] - 0s 188us/sample - loss: 0.5809 - accuracy: 0.7930
# Epoch 138/300
# 1001/1001 [==============================] - 0s 194us/sample - loss: 0.5793 - accuracy: 0.7912
# Epoch 139/300
# 1001/1001 [==============================] - 0s 170us/sample - loss: 0.5798 - accuracy: 0.7932
# Epoch 140/300
# 1001/1001 [==============================] - 0s 176us/sample - loss: 0.5743 - accuracy: 0.7935
# Epoch 141/300
# 1001/1001 [==============================] - 0s 171us/sample - loss: 0.5743 - accuracy: 0.7921
# Epoch 142/300
# 1001/1001 [==============================] - 0s 177us/sample - loss: 0.5733 - accuracy: 0.7945
# Epoch 143/300
# 1001/1001 [==============================] - 0s 188us/sample - loss: 0.5711 - accuracy: 0.7978
# Epoch 144/300
# 1001/1001 [==============================] - 0s 196us/sample - loss: 0.5700 - accuracy: 0.7959
# Epoch 145/300
# 1001/1001 [==============================] - 0s 197us/sample - loss: 0.5669 - accuracy: 0.7954
# Epoch 146/300
# 1001/1001 [==============================] - 0s 179us/sample - loss: 0.5694 - accuracy: 0.7956
# Epoch 147/300
# 1001/1001 [==============================] - 0s 187us/sample - loss: 0.5644 - accuracy: 0.7942
# Epoch 148/300
# 1001/1001 [==============================] - 0s 181us/sample - loss: 0.5855 - accuracy: 0.7909
# Epoch 149/300
# 1001/1001 [==============================] - 0s 170us/sample - loss: 0.5763 - accuracy: 0.7958
# Epoch 150/300
# 1001/1001 [==============================] - 0s 167us/sample - loss: 0.5644 - accuracy: 0.7980
# Epoch 151/300
#  992/1001 [============================>.] - ETA: 0s - loss: 0.5612 - accuracy: 0.7966
# Names After Epoch 150:
# nala
#
# lorily
#
# roe
#
# ylie
#
# marisia
#
# 1001/1001 [==============================] - 1s 620us/sample - loss: 0.5618 - accuracy: 0.7961
# Epoch 152/300
# 1001/1001 [==============================] - 0s 167us/sample - loss: 0.5573 - accuracy: 0.7991
# Epoch 153/300
# 1001/1001 [==============================] - 0s 167us/sample - loss: 0.5585 - accuracy: 0.7986
# Epoch 154/300
# 1001/1001 [==============================] - 0s 183us/sample - loss: 0.5583 - accuracy: 0.7983
# Epoch 155/300
# 1001/1001 [==============================] - 0s 172us/sample - loss: 0.5558 - accuracy: 0.7988
# Epoch 156/300
# 1001/1001 [==============================] - 0s 174us/sample - loss: 0.5576 - accuracy: 0.7991
# Epoch 157/300
# 1001/1001 [==============================] - 0s 179us/sample - loss: 0.5498 - accuracy: 0.8017
# Epoch 158/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.5519 - accuracy: 0.7989
# Epoch 159/300
# 1001/1001 [==============================] - 0s 189us/sample - loss: 0.5508 - accuracy: 0.7983
# Epoch 160/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.5492 - accuracy: 0.8009
# Epoch 161/300
# 1001/1001 [==============================] - 0s 189us/sample - loss: 0.5446 - accuracy: 0.8022
# Epoch 162/300
# 1001/1001 [==============================] - 0s 196us/sample - loss: 0.5452 - accuracy: 0.7990
# Epoch 163/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.5442 - accuracy: 0.8015
# Epoch 164/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.5429 - accuracy: 0.8010
# Epoch 165/300
# 1001/1001 [==============================] - 0s 193us/sample - loss: 0.5460 - accuracy: 0.8003
# Epoch 166/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.5454 - accuracy: 0.8013
# Epoch 167/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.5394 - accuracy: 0.8042
# Epoch 168/300
# 1001/1001 [==============================] - 0s 194us/sample - loss: 0.5385 - accuracy: 0.8028
# Epoch 169/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.5366 - accuracy: 0.8038
# Epoch 170/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.5375 - accuracy: 0.8041
# Epoch 171/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.5330 - accuracy: 0.8046
# Epoch 172/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.5320 - accuracy: 0.8058
# Epoch 173/300
# 1001/1001 [==============================] - 0s 193us/sample - loss: 0.5341 - accuracy: 0.8028
# Epoch 174/300
# 1001/1001 [==============================] - 0s 189us/sample - loss: 0.5274 - accuracy: 0.8057
# Epoch 175/300
# 1001/1001 [==============================] - 0s 189us/sample - loss: 0.5337 - accuracy: 0.8038
# Epoch 176/300
#  896/1001 [=========================>....] - ETA: 0s - loss: 0.5312 - accuracy: 0.8075
# Names After Epoch 175:
# whelly
#
# ulice
#
# aulur
#
# arori
#
# marisia
#
# 1001/1001 [==============================] - 1s 915us/sample - loss: 0.5342 - accuracy: 0.8064
# Epoch 177/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.5307 - accuracy: 0.8058
# Epoch 178/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.5264 - accuracy: 0.8066
# Epoch 179/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.5308 - accuracy: 0.8039
# Epoch 180/300
# 1001/1001 [==============================] - 0s 194us/sample - loss: 0.5287 - accuracy: 0.8047
# Epoch 181/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.5254 - accuracy: 0.8052
# Epoch 182/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.5246 - accuracy: 0.8069
# Epoch 183/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.5244 - accuracy: 0.8035
# Epoch 184/300
# 1001/1001 [==============================] - 0s 193us/sample - loss: 0.5251 - accuracy: 0.8082
# Epoch 185/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.5239 - accuracy: 0.8059
# Epoch 186/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.5209 - accuracy: 0.8063
# Epoch 187/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.5187 - accuracy: 0.8080
# Epoch 188/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.5189 - accuracy: 0.8077
# Epoch 189/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.5191 - accuracy: 0.8082
# Epoch 190/300
# 1001/1001 [==============================] - 0s 191us/sample - loss: 0.5163 - accuracy: 0.8063
# Epoch 191/300
# 1001/1001 [==============================] - 0s 189us/sample - loss: 0.5158 - accuracy: 0.8059
# Epoch 192/300
# 1001/1001 [==============================] - 0s 193us/sample - loss: 0.5187 - accuracy: 0.8075
# Epoch 193/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.5154 - accuracy: 0.8092
# Epoch 194/300
# 1001/1001 [==============================] - 0s 190us/sample - loss: 0.5151 - accuracy: 0.8095
# Epoch 195/300
# 1001/1001 [==============================] - 0s 192us/sample - loss: 0.5200 - accuracy: 0.8078
# Epoch 196/300
# 1001/1001 [==============================] - 0s 222us/sample - loss: 0.5212 - accuracy: 0.8058
# Epoch 197/300
# 1001/1001 [==============================] - 0s 237us/sample - loss: 0.5182 - accuracy: 0.8058
# Epoch 198/300
# 1001/1001 [==============================] - 0s 237us/sample - loss: 0.5080 - accuracy: 0.8080
# Epoch 199/300
# 1001/1001 [==============================] - 0s 240us/sample - loss: 0.5079 - accuracy: 0.8097
# Epoch 200/300
# 1001/1001 [==============================] - 0s 224us/sample - loss: 0.5074 - accuracy: 0.8111
# Epoch 201/300
#  800/1001 [======================>.......] - ETA: 0s - loss: 0.5037 - accuracy: 0.8106
# Names After Epoch 200:
# ella
#
# ylinn
#
# stevie
#
# rynit
#
# emelia
#
# 1001/1001 [==============================] - 1s 993us/sample - loss: 0.5075 - accuracy: 0.8080
# Epoch 202/300
# 1001/1001 [==============================] - 0s 218us/sample - loss: 0.5070 - accuracy: 0.8092
# Epoch 203/300
# 1001/1001 [==============================] - 0s 220us/sample - loss: 0.5071 - accuracy: 0.8077
# Epoch 204/300
# 1001/1001 [==============================] - 0s 216us/sample - loss: 0.5088 - accuracy: 0.8069
# Epoch 205/300
# 1001/1001 [==============================] - 0s 217us/sample - loss: 0.5086 - accuracy: 0.8093
# Epoch 206/300
# 1001/1001 [==============================] - 0s 217us/sample - loss: 0.5071 - accuracy: 0.8077
# Epoch 207/300
# 1001/1001 [==============================] - 0s 216us/sample - loss: 0.5139 - accuracy: 0.8094
# Epoch 208/300
# 1001/1001 [==============================] - 0s 218us/sample - loss: 0.5171 - accuracy: 0.8088
# Epoch 209/300
# 1001/1001 [==============================] - 0s 218us/sample - loss: 0.5058 - accuracy: 0.8086
# Epoch 210/300
# 1001/1001 [==============================] - 0s 224us/sample - loss: 0.5044 - accuracy: 0.8096
# Epoch 211/300
# 1001/1001 [==============================] - 0s 215us/sample - loss: 0.5013 - accuracy: 0.8112
# Epoch 212/300
# 1001/1001 [==============================] - 0s 215us/sample - loss: 0.5025 - accuracy: 0.8103
# Epoch 213/300
# 1001/1001 [==============================] - 0s 224us/sample - loss: 0.5041 - accuracy: 0.8083
# Epoch 214/300
# 1001/1001 [==============================] - 0s 220us/sample - loss: 0.4993 - accuracy: 0.8107
# Epoch 215/300
# 1001/1001 [==============================] - 0s 217us/sample - loss: 0.4985 - accuracy: 0.8129
# Epoch 216/300
# 1001/1001 [==============================] - 0s 216us/sample - loss: 0.5021 - accuracy: 0.8111
# Epoch 217/300
# 1001/1001 [==============================] - 0s 216us/sample - loss: 0.4967 - accuracy: 0.8107
# Epoch 218/300
# 1001/1001 [==============================] - 0s 216us/sample - loss: 0.4958 - accuracy: 0.8110
# Epoch 219/300
# 1001/1001 [==============================] - 0s 216us/sample - loss: 0.4942 - accuracy: 0.8138
# Epoch 220/300
# 1001/1001 [==============================] - 0s 214us/sample - loss: 0.4956 - accuracy: 0.8090
# Epoch 221/300
# 1001/1001 [==============================] - 0s 216us/sample - loss: 0.4985 - accuracy: 0.8137
# Epoch 222/300
# 1001/1001 [==============================] - 0s 216us/sample - loss: 0.5003 - accuracy: 0.8120
# Epoch 223/300
# 1001/1001 [==============================] - 0s 216us/sample - loss: 0.4940 - accuracy: 0.8125
# Epoch 224/300
# 1001/1001 [==============================] - 0s 242us/sample - loss: 0.4963 - accuracy: 0.8122
# Epoch 225/300
# 1001/1001 [==============================] - 0s 241us/sample - loss: 0.4935 - accuracy: 0.8116
# Epoch 226/300
#  800/1001 [======================>.......] - ETA: 0s - loss: 0.4933 - accuracy: 0.8115
# Names After Epoch 225:
# taliyah
#
# innee
#
#
#
# opelye
#
# ella
#
# 1001/1001 [==============================] - 1s 976us/sample - loss: 0.4958 - accuracy: 0.8095
# Epoch 227/300
# 1001/1001 [==============================] - 0s 254us/sample - loss: 0.4935 - accuracy: 0.8112
# Epoch 228/300
# 1001/1001 [==============================] - 0s 251us/sample - loss: 0.4958 - accuracy: 0.8123
# Epoch 229/300
# 1001/1001 [==============================] - 0s 239us/sample - loss: 0.4910 - accuracy: 0.8106
# Epoch 230/300
# 1001/1001 [==============================] - 0s 221us/sample - loss: 0.4944 - accuracy: 0.8135
# Epoch 231/300
# 1001/1001 [==============================] - 0s 233us/sample - loss: 0.4910 - accuracy: 0.8107
# Epoch 232/300
# 1001/1001 [==============================] - 0s 226us/sample - loss: 0.4888 - accuracy: 0.8117
# Epoch 233/300
# 1001/1001 [==============================] - 0s 224us/sample - loss: 0.4888 - accuracy: 0.8121
# Epoch 234/300
# 1001/1001 [==============================] - 0s 224us/sample - loss: 0.4910 - accuracy: 0.8111
# Epoch 235/300
# 1001/1001 [==============================] - 0s 225us/sample - loss: 0.4879 - accuracy: 0.8132
# Epoch 236/300
# 1001/1001 [==============================] - 0s 228us/sample - loss: 0.4897 - accuracy: 0.8113
# Epoch 237/300
# 1001/1001 [==============================] - 0s 224us/sample - loss: 0.4872 - accuracy: 0.8112
# Epoch 238/300
# 1001/1001 [==============================] - 0s 222us/sample - loss: 0.4895 - accuracy: 0.8122
# Epoch 239/300
# 1001/1001 [==============================] - 0s 227us/sample - loss: 0.4893 - accuracy: 0.8118
# Epoch 240/300
# 1001/1001 [==============================] - 0s 229us/sample - loss: 0.4853 - accuracy: 0.8147
# Epoch 241/300
# 1001/1001 [==============================] - 0s 237us/sample - loss: 0.4863 - accuracy: 0.8160
# Epoch 242/300
# 1001/1001 [==============================] - 0s 230us/sample - loss: 0.4893 - accuracy: 0.8126
# Epoch 243/300
# 1001/1001 [==============================] - 0s 225us/sample - loss: 0.4857 - accuracy: 0.8113
# Epoch 244/300
# 1001/1001 [==============================] - 0s 225us/sample - loss: 0.4855 - accuracy: 0.8118
# Epoch 245/300
# 1001/1001 [==============================] - 0s 226us/sample - loss: 0.4854 - accuracy: 0.8120
# Epoch 246/300
# 1001/1001 [==============================] - 0s 222us/sample - loss: 0.4834 - accuracy: 0.8135
# Epoch 247/300
# 1001/1001 [==============================] - 0s 224us/sample - loss: 0.4828 - accuracy: 0.8146
# Epoch 248/300
# 1001/1001 [==============================] - 0s 232us/sample - loss: 0.4825 - accuracy: 0.8134
# Epoch 249/300
# 1001/1001 [==============================] - 0s 225us/sample - loss: 0.4847 - accuracy: 0.8128
# Epoch 250/300
# 1001/1001 [==============================] - 0s 250us/sample - loss: 0.4815 - accuracy: 0.8153
# Epoch 251/300
#  928/1001 [==========================>...] - ETA: 0s - loss: 0.4810 - accuracy: 0.8135
# Names After Epoch 250:
# ryce
#
# ilynna
#
# elesten
#
# aelena
#
# leia
#
# 1001/1001 [==============================] - 1s 1ms/sample - loss: 0.4823 - accuracy: 0.8126
# Epoch 252/300
# 1001/1001 [==============================] - 0s 224us/sample - loss: 0.4821 - accuracy: 0.8149
# Epoch 253/300
# 1001/1001 [==============================] - 0s 223us/sample - loss: 0.4829 - accuracy: 0.8143
# Epoch 254/300
# 1001/1001 [==============================] - 0s 223us/sample - loss: 0.4829 - accuracy: 0.8124
# Epoch 255/300
# 1001/1001 [==============================] - 0s 222us/sample - loss: 0.4812 - accuracy: 0.8120
# Epoch 256/300
# 1001/1001 [==============================] - 0s 225us/sample - loss: 0.4792 - accuracy: 0.8151
# Epoch 257/300
# 1001/1001 [==============================] - 0s 215us/sample - loss: 0.4793 - accuracy: 0.8136
# Epoch 258/300
# 1001/1001 [==============================] - 0s 215us/sample - loss: 0.4842 - accuracy: 0.8128
# Epoch 259/300
# 1001/1001 [==============================] - 0s 220us/sample - loss: 0.4775 - accuracy: 0.8150
# Epoch 260/300
# 1001/1001 [==============================] - 0s 222us/sample - loss: 0.4807 - accuracy: 0.8127
# Epoch 261/300
# 1001/1001 [==============================] - 0s 223us/sample - loss: 0.4823 - accuracy: 0.8132
# Epoch 262/300
# 1001/1001 [==============================] - 0s 218us/sample - loss: 0.4833 - accuracy: 0.8131
# Epoch 263/300
# 1001/1001 [==============================] - 0s 219us/sample - loss: 0.4757 - accuracy: 0.8148
# Epoch 264/300
# 1001/1001 [==============================] - 0s 228us/sample - loss: 0.4773 - accuracy: 0.8136
# Epoch 265/300
# 1001/1001 [==============================] - 0s 221us/sample - loss: 0.4734 - accuracy: 0.8122
# Epoch 266/300
# 1001/1001 [==============================] - 0s 216us/sample - loss: 0.4811 - accuracy: 0.8142
# Epoch 267/300
# 1001/1001 [==============================] - 0s 216us/sample - loss: 0.4774 - accuracy: 0.8123
# Epoch 268/300
# 1001/1001 [==============================] - 0s 225us/sample - loss: 0.4774 - accuracy: 0.8139
# Epoch 269/300
# 1001/1001 [==============================] - 0s 224us/sample - loss: 0.4785 - accuracy: 0.8145
# Epoch 270/300
# 1001/1001 [==============================] - 0s 219us/sample - loss: 0.4752 - accuracy: 0.8152
# Epoch 271/300
# 1001/1001 [==============================] - 0s 221us/sample - loss: 0.4731 - accuracy: 0.8153
# Epoch 272/300
# 1001/1001 [==============================] - 0s 220us/sample - loss: 0.4750 - accuracy: 0.8147
# Epoch 273/300
# 1001/1001 [==============================] - 0s 223us/sample - loss: 0.4771 - accuracy: 0.8144
# Epoch 274/300
# 1001/1001 [==============================] - 0s 222us/sample - loss: 0.4721 - accuracy: 0.8154
# Epoch 275/300
# 1001/1001 [==============================] - 0s 217us/sample - loss: 0.4738 - accuracy: 0.8156
# Epoch 276/300
#  800/1001 [======================>.......] - ETA: 0s - loss: 0.4684 - accuracy: 0.8164
# Names After Epoch 275:
# scelle
#
# adriciny
#
# iver
#
# coreline
#
# elianna
#
# 1001/1001 [==============================] - 1s 1ms/sample - loss: 0.4733 - accuracy: 0.8141
# Epoch 277/300
# 1001/1001 [==============================] - 0s 222us/sample - loss: 0.4743 - accuracy: 0.8153
# Epoch 278/300
# 1001/1001 [==============================] - 0s 222us/sample - loss: 0.4743 - accuracy: 0.8143
# Epoch 279/300
# 1001/1001 [==============================] - 0s 228us/sample - loss: 0.4707 - accuracy: 0.8139
# Epoch 280/300
# 1001/1001 [==============================] - 0s 235us/sample - loss: 0.4695 - accuracy: 0.8149
# Epoch 281/300
# 1001/1001 [==============================] - 0s 223us/sample - loss: 0.4697 - accuracy: 0.8124
# Epoch 282/300
# 1001/1001 [==============================] - 0s 217us/sample - loss: 0.4696 - accuracy: 0.8137
# Epoch 283/300
# 1001/1001 [==============================] - 0s 226us/sample - loss: 0.4697 - accuracy: 0.8135
# Epoch 284/300
# 1001/1001 [==============================] - 0s 225us/sample - loss: 0.4715 - accuracy: 0.8135
# Epoch 285/300
# 1001/1001 [==============================] - 0s 225us/sample - loss: 0.4733 - accuracy: 0.8140
# Epoch 286/300
# 1001/1001 [==============================] - 0s 224us/sample - loss: 0.4701 - accuracy: 0.8136
# Epoch 287/300
# 1001/1001 [==============================] - 0s 230us/sample - loss: 0.4669 - accuracy: 0.8152
# Epoch 288/300
# 1001/1001 [==============================] - 0s 223us/sample - loss: 0.4698 - accuracy: 0.8159
# Epoch 289/300
# 1001/1001 [==============================] - 0s 226us/sample - loss: 0.4727 - accuracy: 0.8118
# Epoch 290/300
# 1001/1001 [==============================] - 0s 215us/sample - loss: 0.4669 - accuracy: 0.8139
# Epoch 291/300
# 1001/1001 [==============================] - 0s 221us/sample - loss: 0.4694 - accuracy: 0.8146
# Epoch 292/300
# 1001/1001 [==============================] - 0s 225us/sample - loss: 0.4714 - accuracy: 0.8161
# Epoch 293/300
# 1001/1001 [==============================] - 0s 237us/sample - loss: 0.4708 - accuracy: 0.8168
# Epoch 294/300
# 1001/1001 [==============================] - 0s 219us/sample - loss: 0.4715 - accuracy: 0.8139
# Epoch 295/300
# 1001/1001 [==============================] - 0s 217us/sample - loss: 0.4696 - accuracy: 0.8146
# Epoch 296/300
# 1001/1001 [==============================] - 0s 218us/sample - loss: 0.4677 - accuracy: 0.8148
# Epoch 297/300
# 1001/1001 [==============================] - 0s 218us/sample - loss: 0.4663 - accuracy: 0.8150
# Epoch 298/300
# 1001/1001 [==============================] - 0s 225us/sample - loss: 0.4683 - accuracy: 0.8169
# Epoch 299/300
# 1001/1001 [==============================] - 0s 218us/sample - loss: 0.4694 - accuracy: 0.8144
# Epoch 300/300
# 1001/1001 [==============================] - 0s 224us/sample - loss: 0.4692 - accuracy: 0.8138

# %% [markdown]
# The model does a good job in generating names which sound similiar to the ones used in the English language. The generated names might not make sense because we don't use them in general. If the dataset had Dinosaur names or something with scientific names, it would make more sense as they would have common endings like 'saurus' etc
